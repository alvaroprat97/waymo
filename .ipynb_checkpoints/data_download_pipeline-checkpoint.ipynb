# %%
import os
import time
import tensorflow.compat.v1 as tf
import pickle

tf.enable_eager_execution() # No need for session to be created. Function instances are run immediately. 

from waymo_open_dataset import dataset_pb2 as open_dataset
from google.cloud import storage

import concurrent.futures as concurr

# CONFIG
project = "Waymo3DObjectDetection"
bucket_name = 'waymo_open_dataset_v_1_2_0_individual_files'
suffix = '.tfrecord'
data_destination = os.getcwd() + "/data/"
download_batch_size = 1

def download_blob(blob, c):
    """
    blob = single file name
    c = file counter
    """
    fname = f"{data_destination}blob_{c}{suffix}"
    blob.download_to_filename(fname)
    return fname

def strip_frame(frame, idx, blob_idx):
    """Strip frame from garbage such as LIDAR data"""
    
    cam_dict = {}
    for i, camera in enumerate(["FRONT", "FRONT_LEFT", "SIDE_LEFT", "FRONT_RIGHT", "SIDE_RIGHT"]):
        cam_dict[camera] = {}
        cam_dict[camera]['image'] = frame.images[i].image
        cam_dict[camera]['velocity'] = frame.images[i].velocity
        cam_dict[camera]['labels'] = frame.camera_labels[i]
        
        cam_dict[camera]['context']={'stats':frame.context.stats, 
                           'name': frame.context.name, 
                           'blob_idx':blob_idx,
                           'time_frame_idx':idx,
                           'timestamp': frame.timestamp_micros}
    return cam_dict

def save_frames(frames, blob_idx, dataset='training'):
    """Save frames into pickle format. To preprocess later"""
    for frame_idx, frame in enumerate(frames):
        for camera, camera_dict in frame.items():
            with open(f'{data_destination}{dataset}/{camera}/blob_{blob_idx}_frame_{frame_idx}.pickle', 'wb') as f:
                # Pickle the 'data' dictionary using the highest protocol available.
                pickle.dump(camera_dict, f, pickle.HIGHEST_PROTOCOL)
    return None

def load_frame(frame_idx, blob_idx, dataset='training'):
    with open(f'{data_destination}{dataset}/blob_{blob_idx}.pickle', 'rb') as f:
        # Load the 'data' dictionary using the highest protocol available.
        return pickle.load(f, pickle.HIGHEST_PROTOCOL)


# Retrieve frames from selected files to download
def get_and_strip_frames_from_one_blob(downloaded_blob, blob_idx):
    # Load into tf record dataset
    dataset = tf.data.TFRecordDataset(downloaded_blob, compression_type='')
    frames = []
    for idx, data in enumerate(dataset):
        frame = open_dataset.Frame()
        frame.ParseFromString(bytearray(data.numpy()))
        # Function to strip away LIDAR and other garbage from frame
        frame = strip_frame(frame, idx, blob_idx)
        frames.append(frame)
    return frames

def download_process_save_1_blob(blob, blob_idx, dataset='training'):
    """Like dem descriptive func names eh?"""

    print(f"Downloading blob_{blob_idx}")
    blob_fname = download_blob(blob, blob_idx)
    
#     print(f"Getting and stripping all frames from blob_{blob_idx}")
    frames = get_and_strip_frames_from_one_blob(blob_fname, blob_idx)

#     print(f"Saving frames for blob {blob_idx}")
    save_frames(frames, blob_idx, dataset)

#     print(f'No longer need tfrecord blob_{blob_idx}. Deleting now.')
    os.remove(f'data/blob_{blob_idx}.tfrecord')

    return f"blob_{blob_idx}"

# %%
# Initialise a client
storage_client = storage.Client(project= project) #storage.Client(project= "Waymo3DObjectDetection", credentials=credentials)
# Create a bucket object for our bucket
bucket = storage_client.get_bucket(bucket_name)
# Get blob files in bucket
blobs = [blob for blob in storage_client.list_blobs(bucket_name, prefix='training/')]

n_blobs = len(blobs) # Number of blobs in the training dataset
print(f'Total number of blobs is {n_blobs}')
# Out:
# /usr/local/lib/python3.6/dist-packages/google/auth/_default.py:69: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# Total number of blobs is 798

# %%
# TRAINING
start = time.time()
downloaded_blobs = []

# Start from idx 610
thread_iterable = [(blob,blob_idx, 'training') for blob_idx, blob in enumerate(blobs)]

# thread_iterable = ((blob,blob_idx, 'training') for blob_idx, blob in enumerate(blobs))

with concurr.ThreadPoolExecutor(max_workers = 2) as executor:

    results = executor.map(lambda args: download_process_save_1_blob(*args), thread_iterable)
    for r in results:
        print(f'\n Time elapsed {time.time() - start}')
        downloaded_blobs.append(r)
        
end = time.time()
print(f'Total time taken {end - start}')
# Out:
# Downloading blob_0
# Downloading blob_1
# Downloading blob_2
#  Time elapsed 24.397799730300903
#
# Downloading blob_3
#
#  Time elapsed 27.30626082420349
# Downloading blob_4
#  Time elapsed 50.84785008430481
#
# Downloading blob_5
#
#  Time elapsed 51.55322766304016
# Downloading blob_6
#
#  Time elapsed 77.04192209243774
# Downloading blob_7
#  Time elapsed 77.47947764396667
#
# Downloading blob_8
#
#  Time elapsed 102.2274956703186
# Downloading blob_9
#  Time elapsed 103.4895966053009
#
# Downloading blob_10
#  Time elapsed 126.99525213241577
#
# Downloading blob_11
#  Time elapsed 132.9642391204834
#
# Downloading blob_12
# Downloading blob_13
#  Time elapsed 157.00641250610352
#
#
#  Time elapsed 157.00861024856567
# Downloading blob_14
# Downloading blob_15
#  Time elapsed 186.48069405555725
#
#
#  Time elapsed 186.48396348953247
# Downloading blob_16
#
#  Time elapsed 211.79796981811523
# Downloading blob_17
#  Time elapsed 215.32360196113586
#
# Downloading blob_18
#
#  Time elapsed 250.21507668495178
# Downloading blob_19
#  Time elapsed 250.97174954414368
#
# Downloading blob_20
# Downloading blob_21
#
#  Time elapsed 281.17538261413574
#
#  Time elapsed 281.17763686180115
# Downloading blob_22
#  Time elapsed 305.8970925807953
#
# Downloading blob_23
#
#  Time elapsed 310.8709542751312
# Downloading blob_24
#  Time elapsed 330.8340628147125
#
# Downloading blob_25
#  Time elapsed 332.2398257255554
#
# Downloading blob_26
#  Time elapsed 359.2499361038208
#
# Downloading blob_27
#
#  Time elapsed 359.46549367904663
# Downloading blob_28
#
#  Time elapsed 384.75587940216064
# Downloading blob_29
#  Time elapsed 388.0894310474396
#
# Downloading blob_30
#  Time elapsed 415.59580659866333
#
# Downloading blob_31
#  Time elapsed 417.7926721572876
#
# Downloading blob_32
#  Time elapsed 442.6401183605194
#
# Downloading blob_33
#  Time elapsed 445.53898334503174
#
# Downloading blob_34
#  Time elapsed 469.1993420124054
#
# Downloading blob_35
#  Time elapsed 470.03067088127136
#
# Downloading blob_36
#  Time elapsed 496.40179324150085
#
# Downloading blob_37
#  Time elapsed 497.5722863674164
#
# Downloading blob_38
# Downloading blob_39
#  Time elapsed 522.6886627674103
#
#
#  Time elapsed 522.6896612644196
# Downloading blob_40
#  Time elapsed 548.8235113620758
#
# Downloading blob_41
#  Time elapsed 553.0693929195404
#
# Downloading blob_42
#  Time elapsed 574.0995314121246
#
# Downloading blob_43
#  Time elapsed 575.5996339321136
#
# Downloading blob_44
#
#  Time elapsed 595.4227428436279
# Downloading blob_45
#  Time elapsed 597.7163109779358
#
# Downloading blob_46
#  Time elapsed 621.3078536987305
#
# Downloading blob_47
#  Time elapsed 623.1612467765808
#
# Downloading blob_48
#  Time elapsed 646.7450997829437
#
# Downloading blob_49
#
#  Time elapsed 647.1154520511627
# Downloading blob_50
#  Time elapsed 673.1917173862457
#
# Downloading blob_51
#  Time elapsed 675.678277015686
#
# Downloading blob_52
#  Time elapsed 701.6746296882629
#
# Downloading blob_53
#  Time elapsed 704.2956490516663
#
# Downloading blob_54
#  Time elapsed 728.293975353241
#
# Downloading blob_55
#
#  Time elapsed 729.6544914245605
# Downloading blob_56
#  Time elapsed 755.884792804718
#
# Downloading blob_57
#  Time elapsed 756.3811433315277
#
# Downloading blob_58
# Downloading blob_59
#
#  Time elapsed 780.3846487998962
#
#  Time elapsed 780.3873035907745
# Downloading blob_60
#  Time elapsed 803.5827558040619
#
# Downloading blob_61
#
#  Time elapsed 807.723441362381
# Downloading blob_62
#  Time elapsed 829.4653143882751
#
# Downloading blob_63
#
#  Time elapsed 831.1553874015808
# Downloading blob_64
#  Time elapsed 853.4774651527405
#
# Downloading blob_65
#  Time elapsed 853.7861707210541
#
# Downloading blob_66
#  Time elapsed 879.2915980815887
#
# Downloading blob_67
#  Time elapsed 882.6549921035767
#
# Downloading blob_68
#  Time elapsed 907.4527766704559
#
# Downloading blob_69
#
#  Time elapsed 908.7638885974884
# Downloading blob_70
#  Time elapsed 933.0301585197449
#
# Downloading blob_71
#
#  Time elapsed 935.2084891796112
# Downloading blob_72
#  Time elapsed 963.9224193096161
#
# Downloading blob_73
#  Time elapsed 964.9486918449402
#
# Downloading blob_74
#  Time elapsed 989.2895753383636
#
# Downloading blob_75
#  Time elapsed 990.2072501182556
#
# Downloading blob_76
# Downloading blob_77
#  Time elapsed 1016.0133607387543
#
#  Time elapsed 1016.0134751796722
#
# Downloading blob_78
# Downloading blob_79
#  Time elapsed 1044.1744952201843
#
#  Time elapsed 1044.175282239914
#
# Downloading blob_80
#  Time elapsed 1072.1252303123474
#
# Downloading blob_81
#  Time elapsed 1073.1736898422241
#
# Downloading blob_82
#  Time elapsed 1098.110282421112
#
# Downloading blob_83
#  Time elapsed 1098.2978723049164
#
# Downloading blob_84
# Downloading blob_85
#  Time elapsed 1125.1148879528046
#
#  Time elapsed 1125.1150586605072
#
# Downloading blob_86
#  Time elapsed 1150.7290823459625
#
# Downloading blob_87
#  Time elapsed 1152.0674350261688
#
# Downloading blob_88
# Downloading blob_89
#  Time elapsed 1177.6010694503784
#
#  Time elapsed 1177.6012346744537
#
# Downloading blob_90
#  Time elapsed 1206.0177099704742
#
# Downloading blob_91
#  Time elapsed 1206.428294658661
#
# Downloading blob_92
# Downloading blob_93
#  Time elapsed 1231.4054896831512
#
#  Time elapsed 1231.4056351184845
#
# Downloading blob_94
#  Time elapsed 1257.1608998775482
#
# Downloading blob_95
#
#  Time elapsed 1257.1865873336792
# Downloading blob_96
#  Time elapsed 1282.5674633979797
#
# Downloading blob_97
#  Time elapsed 1282.7429690361023
#
# Downloading blob_98
#
#  Time elapsed 1310.3166089057922
# Downloading blob_99
#
#  Time elapsed 1310.905755996704
# Downloading blob_100
#  Time elapsed 1336.8583328723907
#
# Downloading blob_101
#  Time elapsed 1337.9236962795258
#
# Downloading blob_102
# Downloading blob_103
#
#  Time elapsed 1363.4997458457947
#
#  Time elapsed 1363.4998798370361
# Downloading blob_104
#  Time elapsed 1389.6683285236359
#
# Downloading blob_105
#  Time elapsed 1390.0888981819153
#
# Downloading blob_106Downloading blob_107
#
#  Time elapsed 1426.5000212192535
#
#
#  Time elapsed 1426.5023715496063
# Downloading blob_108
# Downloading blob_109
#  Time elapsed 1465.0734128952026
#
#  Time elapsed 1465.0735757350922
#
# Downloading blob_110
#  Time elapsed 1502.2296495437622
#
# Downloading blob_111
#  Time elapsed 1502.5171658992767
#
# Downloading blob_112
# Downloading blob_113
#  Time elapsed 1540.460147857666
#
#
#  Time elapsed 1540.4608614444733
# Downloading blob_114
#  Time elapsed 1579.1826646327972
#
# Downloading blob_115
#
#  Time elapsed 1579.8062818050385
# Downloading blob_116Downloading blob_117
#
#
#  Time elapsed 1615.947800397873
#
#  Time elapsed 1615.9485914707184
# Downloading blob_118Downloading blob_119
#
#
#  Time elapsed 1652.825656414032
#
#  Time elapsed 1652.8258316516876
# Downloading blob_120
#  Time elapsed 1691.4524400234222
#
# Downloading blob_121
#
#  Time elapsed 1692.2045650482178
# Downloading blob_122
#  Time elapsed 1729.7655351161957
#
# Downloading blob_123
#
#  Time elapsed 1731.7128419876099
# Downloading blob_124
# Downloading blob_125
#
#  Time elapsed 1763.2835173606873
#
#  Time elapsed 1763.2836282253265
# Downloading blob_126
# Downloading blob_127
#  Time elapsed 1802.8930613994598
#
#
#  Time elapsed 1802.8938345909119
# Downloading blob_128
# Downloading blob_129
#  Time elapsed 1842.0799810886383
#
#  Time elapsed 1842.0803480148315
#
# Downloading blob_130
#  Time elapsed 1880.0864684581757
#
# Downloading blob_131
#  Time elapsed 1880.7442603111267
#
# Downloading blob_132
# Downloading blob_133
#
#  Time elapsed 1927.657361984253
#
#  Time elapsed 1927.6603691577911
# Downloading blob_134
#  Time elapsed 1963.819132566452
#
# Downloading blob_135
#  Time elapsed 1964.9637744426727
#
# Downloading blob_136
#  Time elapsed 2008.8096406459808
#
# Downloading blob_137
#  Time elapsed 2009.0940296649933
#
# Downloading blob_138
#
#  Time elapsed 2047.1998174190521
# Downloading blob_139
#
#  Time elapsed 2047.2001960277557
# Downloading blob_140
#  Time elapsed 2085.7159180641174
#
# Downloading blob_141
#  Time elapsed 2087.166884660721
#
# Downloading blob_142
# Downloading blob_143
#  Time elapsed 2127.092258453369
#
#
#  Time elapsed 2127.0961821079254
# Downloading blob_144
# Downloading blob_145
#  Time elapsed 2168.8103115558624
#
#  Time elapsed 2168.810455560684
#
# Downloading blob_146
# Downloading blob_147
#  Time elapsed 2207.2171442508698
#
#  Time elapsed 2207.2173342704773
#
# Downloading blob_148
#  Time elapsed 2249.4376764297485
#
# Downloading blob_149
#  Time elapsed 2251.1121668815613
#
# Downloading blob_150
#  Time elapsed 2290.273685693741
#
# Downloading blob_151
#  Time elapsed 2290.6190292835236
#
# Downloading blob_152
#  Time elapsed 2325.9216685295105
#
# Downloading blob_153
#  Time elapsed 2326.018324136734
# Downloading blob_154
#
#  Time elapsed 2361.2061851024628
# Downloading blob_155
#
#  Time elapsed 2361.2262032032013
# Downloading blob_156
#  Time elapsed 2397.323609828949
#
# Downloading blob_157
#  Time elapsed 2397.6095044612885
#
# Downloading blob_158
#  Time elapsed 2437.9579672813416
#
# Downloading blob_159
#  Time elapsed 2438.4182205200195
#
# Downloading blob_160
# Downloading blob_161
#  Time elapsed 2478.596015930176
#
#  Time elapsed 2478.596228122711
#
# Downloading blob_162
# Downloading blob_163
#
#  Time elapsed 2517.4469513893127
#
#  Time elapsed 2517.4471757411957
# Downloading blob_170
#  Time elapsed 2660.594094514847
#
# Downloading blob_171
#
#  Time elapsed 2665.8793823719025
# Downloading blob_172
#  Time elapsed 2707.1163244247437
#
# Downloading blob_173
#  Time elapsed 2707.4052295684814
#
# Downloading blob_174
#  Time elapsed 2746.5386533737183
#
# Downloading blob_175
#  Time elapsed 2747.177332639694
#
# Downloading blob_176Downloading blob_177
#
#
#  Time elapsed 2785.433651447296
#
#  Time elapsed 2785.4358189105988
# Downloading blob_178
#  Time elapsed 2826.328097343445
#
# Downloading blob_179
#  Time elapsed 2826.6268413066864
#
# Downloading blob_180Downloading blob_181
#  Time elapsed 2868.98432636261
#
#  Time elapsed 2868.984423160553
#
#
# Downloading blob_182
#
#  Time elapsed 2911.7845182418823
# Downloading blob_183
#  Time elapsed 2912.2361075878143
#
# Downloading blob_184
#  Time elapsed 2953.826735019684
#
# Downloading blob_185
#  Time elapsed 2954.391840696335
#
# Downloading blob_186
# Downloading blob_187
#  Time elapsed 2995.0967433452606
#
#  Time elapsed 2995.0969319343567
#
# Downloading blob_188
#  Time elapsed 3034.5011279582977
#
# Downloading blob_189
#  Time elapsed 3035.6652710437775
#
# Downloading blob_190
# Downloading blob_191
#  Time elapsed 3074.7315549850464
#
#  Time elapsed 3074.7317254543304
#
# Downloading blob_192
#  Time elapsed 3112.7958776950836
#
# Downloading blob_193
#  Time elapsed 3114.3322501182556
#
# Downloading blob_194
#  Time elapsed 3154.2911746501923
#
# Downloading blob_195
#  Time elapsed 3154.692695379257
#
# Downloading blob_196
#  Time elapsed 3194.178856611252
#
# Downloading blob_197
#  Time elapsed 3195.6680252552032
#
# Downloading blob_198
#  Time elapsed 3233.8914971351624
#
# Downloading blob_199
#  Time elapsed 3235.9495849609375
#
# Downloading blob_200
# Downloading blob_201
#  Time elapsed 3271.1833243370056
#
#
#  Time elapsed 3271.1857097148895
# Downloading blob_202
#  Time elapsed 3312.957466840744
#
# Downloading blob_203
#  Time elapsed 3313.5436646938324
#
# Downloading blob_204
# Downloading blob_205
#  Time elapsed 3355.410941839218
#
#  Time elapsed 3355.4110906124115
#
# Downloading blob_206
# Downloading blob_207
#  Time elapsed 3392.202444076538
#
#
#  Time elapsed 3392.2032704353333
# Downloading blob_208
# Downloading blob_209
#  Time elapsed 3437.5462901592255
#
#
#  Time elapsed 3437.54709148407
# Downloading blob_210
#  Time elapsed 3478.0499296188354
#
# Downloading blob_211
#
#  Time elapsed 3478.9302611351013
# Downloading blob_212
#  Time elapsed 3520.732007741928
#
# Downloading blob_213
#  Time elapsed 3521.5454483032227
#
# Downloading blob_214
#  Time elapsed 3555.2758688926697
#
# Downloading blob_215
#  Time elapsed 3561.082357406616
#
# Downloading blob_216
#  Time elapsed 3584.136383295059
#
# Downloading blob_217
#  Time elapsed 3594.0111334323883
#
# Downloading blob_218
#  Time elapsed 3611.110007286072
#
# Downloading blob_219
#  Time elapsed 3624.455730676651
#
# Downloading blob_220
#  Time elapsed 3650.2191433906555
#
# Downloading blob_221
#  Time elapsed 3663.0187957286835
#
# Downloading blob_222
#  Time elapsed 3706.1060225963593
#
# Downloading blob_223
#  Time elapsed 3707.3505034446716
#
# Downloading blob_224
# Downloading blob_225
#  Time elapsed 3747.310175180435
#
#
#  Time elapsed 3747.310345172882
# Downloading blob_226
#  Time elapsed 3789.757246732712
#
# Downloading blob_227
#  Time elapsed 3790.7121238708496
#
# Downloading blob_228
# Downloading blob_229
#  Time elapsed 3832.1446540355682
#
#
#  Time elapsed 3832.147182226181
# Downloading blob_230
# Downloading blob_231
#  Time elapsed 3871.448121547699
#
#
#  Time elapsed 3871.448394060135
# Downloading blob_232Downloading blob_233
#
#  Time elapsed 3910.0550878047943
#
#  Time elapsed 3910.0551767349243
#
# Downloading blob_234
#  Time elapsed 3950.6066813468933
#
# Downloading blob_235
#  Time elapsed 3950.8802440166473
#
# Downloading blob_236
#  Time elapsed 3990.525700569153
#
# Downloading blob_237
#  Time elapsed 3990.844823360443
#
# Downloading blob_238
#  Time elapsed 4030.9231054782867
#
# Downloading blob_239
#  Time elapsed 4032.2282984256744
#
# Downloading blob_240
# Downloading blob_241
#  Time elapsed 4073.2825515270233
#
#  Time elapsed 4073.2827336788177
#
# Downloading blob_242
#  Time elapsed 4106.982303142548
#
# Downloading blob_243
#  Time elapsed 4113.419783592224
#
# Downloading blob_244
#  Time elapsed 4132.126877784729
#
# Downloading blob_245
#
#  Time elapsed 4144.116711854935
# Downloading blob_246
#  Time elapsed 4158.138893604279
#
# Downloading blob_247
#  Time elapsed 4165.937922477722
#
# Downloading blob_248
#  Time elapsed 4207.0928683280945
#
# Downloading blob_249
#  Time elapsed 4208.542343616486
#
# Downloading blob_250
# Downloading blob_251
#  Time elapsed 4245.43899512291
#
#
#  Time elapsed 4245.439405441284
# Downloading blob_252
#  Time elapsed 4283.497708559036
#
# Downloading blob_253
#
#  Time elapsed 4283.882354021072
# Downloading blob_254
# Downloading blob_255
#  Time elapsed 4320.961555480957
#
#  Time elapsed 4320.961751461029
#
# Downloading blob_256
#  Time elapsed 4358.387757778168
#
# Downloading blob_257
#
#  Time elapsed 4359.327892780304
# Downloading blob_258
#  Time elapsed 4393.869251251221
#
# Downloading blob_259
#
#  Time elapsed 4396.328352212906
# Downloading blob_260
#  Time elapsed 4434.557923555374
#
# Downloading blob_261
#  Time elapsed 4434.967029333115
#
# Downloading blob_262
#  Time elapsed 4471.855542182922
#
# Downloading blob_263
#  Time elapsed 4472.184131622314
#
# Downloading blob_264
#  Time elapsed 4511.518694400787
#
# Downloading blob_265
#  Time elapsed 4512.0839104652405
#
# Downloading blob_266
# Downloading blob_267
#  Time elapsed 4546.932521104813
#
#
#  Time elapsed 4546.935261487961
# Downloading blob_268
#  Time elapsed 4580.849891424179
#
# Downloading blob_269
#
#  Time elapsed 4584.692838430405
# Downloading blob_270
#  Time elapsed 4616.243601560593
#
# Downloading blob_271
#  Time elapsed 4619.7933049201965
#
# Downloading blob_272
#  Time elapsed 4647.167812347412
#
# Downloading blob_273
#  Time elapsed 4655.722363710403
#
# Downloading blob_274
#  Time elapsed 4686.810490369797
#
# Downloading blob_275
#
#  Time elapsed 4690.567327737808
# Downloading blob_276
#  Time elapsed 4731.747196435928
#
# Downloading blob_277
#  Time elapsed 4732.3353571891785
#
# Downloading blob_278
#  Time elapsed 4775.816599369049
#
# Downloading blob_279
#  Time elapsed 4775.9714386463165
#
# Downloading blob_280
#  Time elapsed 4812.929548501968
#
# Downloading blob_281
#  Time elapsed 4814.108008861542
#
# Downloading blob_282
#  Time elapsed 4851.224721908569
#
# Downloading blob_283
#  Time elapsed 4853.483324289322
#
# Downloading blob_284
#  Time elapsed 4893.923852682114
#
# Downloading blob_285
#  Time elapsed 4895.149027109146
#
# Downloading blob_286
# Downloading blob_287
#  Time elapsed 4935.746433734894
#
#  Time elapsed 4935.746596097946
#
# Downloading blob_294
#  Time elapsed 5087.89452123642
#
# Downloading blob_295
#
#  Time elapsed 5088.151224851608
# Downloading blob_296
#  Time elapsed 5127.397547245026
#
# Downloading blob_297
#
#  Time elapsed 5127.923734664917
# Downloading blob_298
#  Time elapsed 5162.254794597626
#
# Downloading blob_299
#  Time elapsed 5162.975527524948
#
# Downloading blob_300
# Downloading blob_301
#
#  Time elapsed 5203.724124670029
#
#  Time elapsed 5203.724213838577
# Downloading blob_302
#  Time elapsed 5247.478063106537
#
# Downloading blob_303
#  Time elapsed 5247.715934991837
#
# Downloading blob_304
#  Time elapsed 5291.162703752518
#
# Downloading blob_305
#
#  Time elapsed 5291.778485059738
# Downloading blob_306Downloading blob_307
#
#
#  Time elapsed 5333.399071931839
#
#  Time elapsed 5333.399161577225
# Downloading blob_308
# Downloading blob_309
#  Time elapsed 5378.538645982742
#
#
#  Time elapsed 5378.539228439331
# Downloading blob_310
# Downloading blob_311
#  Time elapsed 5415.580835580826
#
#  Time elapsed 5415.580941200256
#
# Downloading blob_312
#  Time elapsed 5453.47865819931
#
# Downloading blob_313
#  Time elapsed 5453.598523378372
#
# Downloading blob_314
# Downloading blob_315
#
#  Time elapsed 5497.834186077118
#
#  Time elapsed 5497.834309339523
# Downloading blob_316
#  Time elapsed 5542.711978673935
# Downloading blob_317
#
#  Time elapsed 5543.642785549164
# Downloading blob_318
#  Time elapsed 5582.784359693527
#
# Downloading blob_319
#  Time elapsed 5583.658168792725
#
# Downloading blob_320
#  Time elapsed 5625.355860233307
#
# Downloading blob_321
#  Time elapsed 5625.375597953796
#
# Downloading blob_322
# Downloading blob_323
#  Time elapsed 5668.981666564941
#
#
#  Time elapsed 5668.983967781067
# Downloading blob_324
#  Time elapsed 5709.166360616684
#
# Downloading blob_325
#
#  Time elapsed 5710.0905838012695
# Downloading blob_326
#  Time elapsed 5747.624959230423
#
# Downloading blob_327
#
#  Time elapsed 5748.207949876785
# Downloading blob_328
#  Time elapsed 5787.35852265358
#
# Downloading blob_329
#
#  Time elapsed 5787.80326628685
# Downloading blob_330
#  Time elapsed 5825.390530824661
#
# Downloading blob_331
#  Time elapsed 5825.686336040497
#
# Downloading blob_332
# Downloading blob_333
#  Time elapsed 5865.504799127579
#
#  Time elapsed 5865.504916906357
#
# Downloading blob_334
# Downloading blob_335
#
#  Time elapsed 5903.931147813797
#
#  Time elapsed 5903.931469678879
# Downloading blob_336
# Downloading blob_337
#  Time elapsed 5939.852366685867
#
#  Time elapsed 5939.852463960648
#
# Downloading blob_338
#  Time elapsed 5977.90753531456
#
# Downloading blob_339
#  Time elapsed 5978.471731424332
#
# Downloading blob_340
#  Time elapsed 6019.650561332703
#
# Downloading blob_341
#  Time elapsed 6019.943334102631
#
# Downloading blob_342
# Downloading blob_343
#  Time elapsed 6063.523935556412
#
#  Time elapsed 6063.524092674255
#
# Downloading blob_344
#  Time elapsed 6096.676327705383
#
# Downloading blob_345
#  Time elapsed 6097.428896665573
#
# Downloading blob_346
#  Time elapsed 6136.819146633148
#
# Downloading blob_347
#  Time elapsed 6137.429216146469
#
# Downloading blob_348
#  Time elapsed 6174.345144271851
#
# Downloading blob_349
#
#  Time elapsed 6174.944273471832
# Downloading blob_350
#  Time elapsed 6211.990929841995
#
# Downloading blob_351
#  Time elapsed 6212.176950216293
#
# Downloading blob_352Downloading blob_353
#
#
#  Time elapsed 6252.937535047531
#
#  Time elapsed 6252.9376854896545
# Downloading blob_354
#  Time elapsed 6288.778294801712
#
# Downloading blob_355
#  Time elapsed 6289.468259572983
#
# Downloading blob_356
# Downloading blob_357
#  Time elapsed 6331.687273025513
#
#
#  Time elapsed 6331.687478065491
# Downloading blob_358
#
#  Time elapsed 6371.329300403595
# Downloading blob_359
#  Time elapsed 6374.759298324585
#
# Downloading blob_360
#  Time elapsed 6413.227874040604
#
# Downloading blob_361
#  Time elapsed 6414.367515325546
#
# Downloading blob_362
# Downloading blob_363
#  Time elapsed 6457.164661645889
#
#  Time elapsed 6457.1648869514465
#
# Downloading blob_364
#  Time elapsed 6495.819169282913
#
# Downloading blob_365
#  Time elapsed 6496.688514709473
#
# Downloading blob_366
#  Time elapsed 6536.086028575897
#
# Downloading blob_367
#  Time elapsed 6536.740401029587
#
# Downloading blob_368
#  Time elapsed 6569.53786110878
#
# Downloading blob_369
#  Time elapsed 6571.018071651459
#
# Downloading blob_370
#  Time elapsed 6610.100101470947
#
# Downloading blob_371
#
#  Time elapsed 6610.379023313522
# Downloading blob_372
# Downloading blob_373
#  Time elapsed 6648.566265583038
#
#  Time elapsed 6648.566561937332
#
# Downloading blob_374
#  Time elapsed 6685.355598688126
#
# Downloading blob_375
#
#  Time elapsed 6685.356691360474
# Downloading blob_376
# Downloading blob_377
#  Time elapsed 6720.239476919174
#
#  Time elapsed 6720.239593029022
#
# Downloading blob_384
#  Time elapsed 6882.97630405426
#
# Downloading blob_385
#  Time elapsed 6884.373396873474
#
# Downloading blob_386
# Downloading blob_387
#  Time elapsed 6924.260272264481
#
#
#  Time elapsed 6924.260484457016
# Downloading blob_388
# Downloading blob_389
#  Time elapsed 6964.4894115924835
#
#  Time elapsed 6964.489691019058
#
# Downloading blob_390
#  Time elapsed 6998.332875013351
#
# Downloading blob_391
#  Time elapsed 6999.022924184799
#
# Downloading blob_392
# Downloading blob_393
#  Time elapsed 7035.732370138168
#
#  Time elapsed 7035.732494592667
#
# Downloading blob_394
# Downloading blob_395
#  Time elapsed 7074.896795988083
#
#
#  Time elapsed 7074.898010730743
# Downloading blob_396
#  Time elapsed 7113.170752048492
#
# Downloading blob_397
#  Time elapsed 7113.2476353645325
#
# Downloading blob_398
#  Time elapsed 7155.878937959671
#
# Downloading blob_399
#  Time elapsed 7157.871863603592
#
# Downloading blob_400
#  Time elapsed 7199.625963687897
#
# Downloading blob_401
#
#  Time elapsed 7201.753560781479
# Downloading blob_402
# Downloading blob_403
#  Time elapsed 7238.436735630035
#
#  Time elapsed 7238.4369423389435
#
# Downloading blob_404
#  Time elapsed 7279.20357465744
#
# Downloading blob_405
#  Time elapsed 7279.484229564667
#
# Downloading blob_406
#  Time elapsed 7321.369263410568
#
# Downloading blob_407
#  Time elapsed 7321.658564090729
#
# Downloading blob_408
# Downloading blob_409
#  Time elapsed 7363.224854469299
#
#  Time elapsed 7363.224980354309
#
# Downloading blob_410
#  Time elapsed 7402.87694478035
#
# Downloading blob_411
#  Time elapsed 7405.110376119614
#
# Downloading blob_412
# Downloading blob_413
#
#  Time elapsed 7445.9404311180115
#
#  Time elapsed 7445.941274404526
# Downloading blob_414
# Downloading blob_415
#  Time elapsed 7486.077174663544
#
#  Time elapsed 7486.0773158073425
#
# Downloading blob_416Downloading blob_417
#  Time elapsed 7522.728374958038
#
#  Time elapsed 7522.728560686111
#
#
# Downloading blob_418
# Downloading blob_419
#  Time elapsed 7562.750920295715
#
#
#  Time elapsed 7562.751178741455
# Downloading blob_420
#
#  Time elapsed 7599.136921882629
# Downloading blob_421
#
#  Time elapsed 7599.473700761795
# Downloading blob_422
#  Time elapsed 7641.059462785721
#
# Downloading blob_423
#  Time elapsed 7641.366963386536
#
# Downloading blob_424
# Downloading blob_425
#  Time elapsed 7676.286751031876
#
#  Time elapsed 7676.286917686462
#
# Downloading blob_426
#  Time elapsed 7716.314460992813
#
# Downloading blob_427
#  Time elapsed 7718.888766288757
#
# Downloading blob_428
#  Time elapsed 7756.602072477341
#
# Downloading blob_429
#  Time elapsed 7757.328262805939
#
# Downloading blob_430
#  Time elapsed 7796.760370254517
#
# Downloading blob_431
#
#  Time elapsed 7797.43954205513
# Downloading blob_432
# Downloading blob_433
#  Time elapsed 7839.131368398666
#
#  Time elapsed 7839.131504774094
#
# Downloading blob_434
#  Time elapsed 7879.8878791332245
#
# Downloading blob_435
#  Time elapsed 7880.295273065567
#
# Downloading blob_436
# Downloading blob_437
#
#  Time elapsed 7919.049286365509
#
#  Time elapsed 7919.052300453186
# Downloading blob_438
# Downloading blob_439
#  Time elapsed 7968.488881826401
#
#  Time elapsed 7968.488999128342
#
# Downloading blob_440
#  Time elapsed 8007.214309930801
#
# Downloading blob_441
#  Time elapsed 8008.005220651627
#
# Downloading blob_442Downloading blob_443
#
#
#  Time elapsed 8047.702739715576
#
#  Time elapsed 8047.702821731567
# Downloading blob_444
# Downloading blob_445
#  Time elapsed 8082.6920466423035
#
#
#  Time elapsed 8082.692880868912
# Downloading blob_446
# Downloading blob_447
#
#  Time elapsed 8122.999628067017
#
#  Time elapsed 8122.999716520309
# Downloading blob_448
#  Time elapsed 8160.907645940781
#
# Downloading blob_449
#  Time elapsed 8161.639861822128
#
# Downloading blob_450
# Downloading blob_451
#  Time elapsed 8202.220340013504
#
#  Time elapsed 8202.220423698425
#
# Downloading blob_452
#  Time elapsed 8246.900475502014
#
# Downloading blob_453
#
#  Time elapsed 8248.673164606094
# Downloading blob_454
# Downloading blob_455
#  Time elapsed 8286.571853160858
#
#  Time elapsed 8286.571956157684
#
# Downloading blob_456
#  Time elapsed 8327.039871454239
#
# Downloading blob_457
#  Time elapsed 8327.675333976746
#
# Downloading blob_458
# Downloading blob_459
#  Time elapsed 8368.90825843811
#
#  Time elapsed 8368.908420085907
#
# Downloading blob_460
# Downloading blob_461
#
#  Time elapsed 8406.656573057175
#
#  Time elapsed 8406.656683444977
# Downloading blob_462
# Downloading blob_463
#  Time elapsed 8445.661440134048
#
#
#  Time elapsed 8445.662392377853
# Downloading blob_464
# Downloading blob_465
#  Time elapsed 8480.175722122192
#
#  Time elapsed 8480.175861597061
#
# Downloading blob_466Downloading blob_467
#
#  Time elapsed 8519.612014055252
#
#  Time elapsed 8519.612113952637
#
# Downloading blob_468
#  Time elapsed 8560.090666770935
#
# Downloading blob_469
#  Time elapsed 8560.350849866867
#
# Downloading blob_470
# Downloading blob_471
#  Time elapsed 8597.331419944763
#
#  Time elapsed 8597.331518173218
#
# Downloading blob_472
#  Time elapsed 8636.55933022499
#
# Downloading blob_473
#  Time elapsed 8636.838522195816
#
# Downloading blob_474
# Downloading blob_475
#
#  Time elapsed 8675.73918557167
#
#  Time elapsed 8675.739272117615
# Downloading blob_476
# Downloading blob_477
#  Time elapsed 8691.850664377213
#
#
#  Time elapsed 8691.851590633392
# Downloading blob_478
#  Time elapsed 8731.438796758652
#
# Downloading blob_479
#  Time elapsed 8731.724051952362
#
# Downloading blob_480
#  Time elapsed 8770.60246014595
#
# Downloading blob_481
#  Time elapsed 8770.622926473618
#
# Downloading blob_482
# Downloading blob_483
#
#  Time elapsed 8805.744594097137
#
#  Time elapsed 8805.744791507721
# Downloading blob_484
# Downloading blob_485
#  Time elapsed 8842.26822400093
#
#
#  Time elapsed 8842.268498182297
# Downloading blob_486
#  Time elapsed 8885.855516195297
#
# Downloading blob_487
#  Time elapsed 8888.863206863403
#
# Downloading blob_488
# Downloading blob_489
#
#  Time elapsed 8930.342457294464
#
#  Time elapsed 8930.342804670334
# Downloading blob_490
#  Time elapsed 8971.417881250381
#
# Downloading blob_491
#  Time elapsed 8973.560017347336
#
# Downloading blob_492
#  Time elapsed 9010.416852235794
#
# Downloading blob_493
#  Time elapsed 9012.366620063782
#
# Downloading blob_494
#  Time elapsed 9049.619965314865
#
# Downloading blob_495
#  Time elapsed 9049.980363368988
#
# Downloading blob_496
# Downloading blob_497
#  Time elapsed 9090.253347158432
#
#
#  Time elapsed 9090.254802942276
# Downloading blob_498
# Downloading blob_499
#
#  Time elapsed 9134.471911907196
#
#  Time elapsed 9134.472084522247
# Downloading blob_500
# Downloading blob_501
#  Time elapsed 9176.252535581589
#
#  Time elapsed 9176.252698659897
#
# Downloading blob_508
#  Time elapsed 9328.416490077972Downloading blob_509
#
#
#  Time elapsed 9328.41712474823
#
# Downloading blob_510
# Downloading blob_511
#
#  Time elapsed 9369.26660490036
#
#  Time elapsed 9369.270254611969
# Downloading blob_512
# Downloading blob_513
#  Time elapsed 9413.893285512924
#
#  Time elapsed 9413.893461227417
#
# Downloading blob_514
# Downloading blob_515
#
#  Time elapsed 9455.182399749756
#
#  Time elapsed 9455.182533025742
# Downloading blob_516
#  Time elapsed 9493.00486111641
#
# Downloading blob_517
#
#  Time elapsed 9493.266024589539
# Downloading blob_518
# Downloading blob_519
#  Time elapsed 9529.335506439209
#
#  Time elapsed 9529.335616350174
#
# Downloading blob_520
#  Time elapsed 9571.395161867142
#
# Downloading blob_521
#
#  Time elapsed 9571.97420668602
# Downloading blob_522
# Downloading blob_523
#  Time elapsed 9615.873482465744
#
#  Time elapsed 9615.873575687408
#
# Downloading blob_524
# Downloading blob_525
#
#  Time elapsed 9653.755425453186
#
#  Time elapsed 9653.75784444809
# Downloading blob_526
#  Time elapsed 9695.774852275848
#
# Downloading blob_527
#  Time elapsed 9695.93249964714
#
# Downloading blob_528
#  Time elapsed 9733.796864271164
#
# Downloading blob_529
#
#  Time elapsed 9734.675716638565
# Downloading blob_530Downloading blob_531
#
#  Time elapsed 9776.011664390564
#
#  Time elapsed 9776.014110565186
#
# Downloading blob_532
# Downloading blob_533
#  Time elapsed 9816.90734410286
#
#  Time elapsed 9816.907471895218
#
# Downloading blob_534
# Downloading blob_535
#  Time elapsed 9857.310604572296
#
#
#  Time elapsed 9857.310967206955
# Downloading blob_536
# Downloading blob_537
#  Time elapsed 9894.292914628983
#
#
#  Time elapsed 9894.293758869171
# Downloading blob_538
#  Time elapsed 9934.211245298386
#
# Downloading blob_539
#  Time elapsed 9934.235661029816
#
# Downloading blob_540
# Downloading blob_541
#
#  Time elapsed 9972.760815143585
#
#  Time elapsed 9972.761000871658
# Downloading blob_542
# Downloading blob_543
#  Time elapsed 10013.467996835709
#
#  Time elapsed 10013.46811580658
#
# Downloading blob_544Downloading blob_545
#
#
#  Time elapsed 10048.360113620758
#
#  Time elapsed 10048.360198020935
# Downloading blob_546
#  Time elapsed 10091.259868383408
#
# Downloading blob_547
#  Time elapsed 10094.450489282608
#
# Downloading blob_548
# Downloading blob_549
#
#  Time elapsed 10135.675171613693
#
#  Time elapsed 10135.67750954628
# Downloading blob_550
# Downloading blob_551
#
#  Time elapsed 10169.902265071869
#
#  Time elapsed 10169.902408838272
# Downloading blob_552
#  Time elapsed 10204.7618227005
#
# Downloading blob_553
#
#  Time elapsed 10205.62312579155
# Downloading blob_554
#  Time elapsed 10245.185541391373
#
# Downloading blob_555
#
#  Time elapsed 10246.354701042175
# Downloading blob_556
# Downloading blob_557
#
#  Time elapsed 10289.087550401688
#
#  Time elapsed 10289.087749004364
# Downloading blob_558
#  Time elapsed 10328.1208319664
#
# Downloading blob_559
#
#  Time elapsed 10328.121414422989
# Downloading blob_560
#
#  Time elapsed 10365.208528280258
# Downloading blob_561
#  Time elapsed 10365.539123535156
#
# Downloading blob_562
# Downloading blob_563
#
#  Time elapsed 10403.717575073242
#
#  Time elapsed 10403.718181610107
# Downloading blob_564
# Downloading blob_565
#  Time elapsed 10442.896581411362
#
#  Time elapsed 10442.896716117859
#
# Downloading blob_566
#  Time elapsed 10483.320029973984
#
# Downloading blob_567
#  Time elapsed 10483.754269361496
#
# Downloading blob_568
#  Time elapsed 10519.843641996384
#
# Downloading blob_569
#  Time elapsed 10520.463054180145
#
# Downloading blob_570
# Downloading blob_571
#  Time elapsed 10562.518256902695
#
#  Time elapsed 10562.518342733383
#
# Downloading blob_572
#  Time elapsed 10600.610515594482
#
# Downloading blob_573
#  Time elapsed 10600.831183671951
#
# Downloading blob_574
#  Time elapsed 10638.902729272842
#
# Downloading blob_575
#
#  Time elapsed 10640.0033056736
# Downloading blob_576
# Downloading blob_577
#  Time elapsed 10681.156525850296
#
#  Time elapsed 10681.156774044037
#
# Downloading blob_578
# Downloading blob_579
#  Time elapsed 10724.050985574722
#
#  Time elapsed 10724.051146268845
#
# Downloading blob_580
#  Time elapsed 10766.42251944542
#
# Downloading blob_581
#  Time elapsed 10766.696687698364
#
# Downloading blob_582
# Downloading blob_583
#  Time elapsed 10801.376101732254
#
#  Time elapsed 10801.376231908798
#
# Downloading blob_584
# Downloading blob_585
#  Time elapsed 10838.448865175247
#
#  Time elapsed 10838.44896888733
#
# Downloading blob_586
# Downloading blob_587
#  Time elapsed 10874.053083181381
#
#  Time elapsed 10874.053169488907
#
# Downloading blob_588
#  Time elapsed 10911.673491954803
#
# Downloading blob_589
#  Time elapsed 10911.790382623672
#
# Downloading blob_590
# Downloading blob_591
#  Time elapsed 10948.96389245987
#
#  Time elapsed 10948.964020729065
#
# Downloading blob_592
#  Time elapsed 10987.14979171753
#
# Downloading blob_593
#  Time elapsed 10987.44283246994
#
# Downloading blob_594
#  Time elapsed 11023.403361558914
#
# Downloading blob_595
#  Time elapsed 11023.668674945831
#
# Downloading blob_596
#  Time elapsed 11061.814636468887
#
# Downloading blob_597
#
#  Time elapsed 11062.036886453629
# Downloading blob_598Downloading blob_599
#
#  Time elapsed 11101.080298185349
#
#  Time elapsed 11101.080396175385
#
# Downloading blob_600
#  Time elapsed 11138.676475524902
#
# Downloading blob_601
#
#  Time elapsed 11139.890805244446
# Downloading blob_602
#  Time elapsed 11176.749576807022
#
# Downloading blob_603
#
#  Time elapsed 11178.368239879608
# Downloading blob_604
#  Time elapsed 11222.821423768997
#
# Downloading blob_605
#  Time elapsed 11224.487683057785
#
# Downloading blob_606
#
#  Time elapsed 11259.776947498322
# Downloading blob_607
#
#  Time elapsed 11260.321479082108
# Downloading blob_608
#  Time elapsed 11300.84297823906
#
# Downloading blob_609
#  Time elapsed 11300.969700574875
#
# Downloading blob_610
#  Time elapsed 11336.072889328003
#
# Downloading blob_611
#
#  Time elapsed 11338.127525091171
# Downloading blob_612
#
#  Time elapsed 11375.12379360199
# Downloading blob_613
#  Time elapsed 11375.713835477829
#
# Downloading blob_614
# Downloading blob_615
#  Time elapsed 11419.51951622963
#
#  Time elapsed 11419.519645929337
#
# Downloading blob_616
#
#  Time elapsed 11460.213286399841
# Downloading blob_617
#  Time elapsed 11460.779729366302
#
# Downloading blob_618
# Downloading blob_619
#  Time elapsed 11502.173384666443
#
#  Time elapsed 11502.173500061035
#
# Downloading blob_620
#  Time elapsed 11540.473088502884
#
# Downloading blob_621
#  Time elapsed 11540.883653640747
#
# Downloading blob_622
#  Time elapsed 11577.895515680313
#
# Downloading blob_623
#  Time elapsed 11578.184262990952
#
# Downloading blob_624
# Downloading blob_625
#
#  Time elapsed 11617.806655168533
#
#  Time elapsed 11617.806802511215
# Downloading blob_626
#  Time elapsed 11648.85035443306
#
# Downloading blob_627
#  Time elapsed 11659.439836263657
#
# Downloading blob_628
#  Time elapsed 11678.267481088638
#
# Downloading blob_629
#
#  Time elapsed 11682.744439125061
# Downloading blob_630
#  Time elapsed 11720.389431715012
#
# Downloading blob_631
#  Time elapsed 11720.848087787628
#
# Downloading blob_632
#
#  Time elapsed 11759.785452127457
# Downloading blob_633
#
#  Time elapsed 11760.971068382263
# Downloading blob_634Downloading blob_635
#
#  Time elapsed 11796.722533464432
#
#  Time elapsed 11796.722680330276
#
# Downloading blob_636
#  Time elapsed 11826.319087982178
#
# Downloading blob_637
#  Time elapsed 11830.037066936493
#
# Downloading blob_638
#  Time elapsed 11866.998615264893
#
# Downloading blob_639
#  Time elapsed 11867.25579380989
#
# Downloading blob_640
#  Time elapsed 11907.919927835464
#
# Downloading blob_641
#
#  Time elapsed 11909.128427028656
# Downloading blob_642
# Downloading blob_643
#
#  Time elapsed 11953.703551054
#
#  Time elapsed 11953.703670978546
# Downloading blob_644
# Downloading blob_645
#  Time elapsed 11999.783445358276
#
#  Time elapsed 11999.783560037613
#
# Downloading blob_646
#  Time elapsed 12039.106375455856
#
# Downloading blob_647
#  Time elapsed 12039.791391849518
#
# Downloading blob_648Downloading blob_649
#
#  Time elapsed 12080.833261728287
#
#
#  Time elapsed 12080.839803934097
# Downloading blob_650
#  Time elapsed 12120.139984369278
#
# Downloading blob_651
#  Time elapsed 12120.155570268631
#
# Downloading blob_652
# Downloading blob_653
#  Time elapsed 12161.990410327911
#
#  Time elapsed 12161.990646362305
#
# Downloading blob_654
#  Time elapsed 12203.023817777634
#
# Downloading blob_655
#  Time elapsed 12203.316625595093
#
# Downloading blob_656
# Downloading blob_657
#  Time elapsed 12240.964641809464
#
#  Time elapsed 12240.964749097824
#
# Downloading blob_658
# Downloading blob_659
#
#  Time elapsed 12278.220841646194
#
#  Time elapsed 12278.221293449402
# Downloading blob_660
# Downloading blob_661
#  Time elapsed 12318.651911735535
#
#  Time elapsed 12318.652039051056
#
# Downloading blob_662
# Downloading blob_663
#  Time elapsed 12354.225227117538
#
#
#  Time elapsed 12354.229430675507
# Downloading blob_664
#  Time elapsed 12389.055057764053
#
# Downloading blob_665
#  Time elapsed 12391.093096971512
#
# Downloading blob_666
#  Time elapsed 12432.706857919693
#
# Downloading blob_667
#  Time elapsed 12432.96388554573
#
# Downloading blob_668
#  Time elapsed 12476.786099672318
#
# Downloading blob_669
#  Time elapsed 12477.48811340332
#
# Downloading blob_670
#  Time elapsed 12516.353792905807
#
# Downloading blob_671
#  Time elapsed 12516.722219705582
#
# Downloading blob_672Downloading blob_673
#
#
#  Time elapsed 12557.416562318802
#
#  Time elapsed 12557.416645288467
# Downloading blob_674
#  Time elapsed 12597.336179494858
#
# Downloading blob_675
#  Time elapsed 12597.64664030075
#
# Downloading blob_676Downloading blob_677
#
#  Time elapsed 12641.107538700104
#
#  Time elapsed 12641.107643604279
#
# Downloading blob_678
#  Time elapsed 12683.927767038345
#
# Downloading blob_679
#  Time elapsed 12684.314920186996
#
# Downloading blob_680
#
#  Time elapsed 12719.731959104538
# Downloading blob_681
#  Time elapsed 12719.732965230942
#
# Downloading blob_682
#  Time elapsed 12763.29192018509
#
# Downloading blob_683
#  Time elapsed 12763.56850028038
#
# Downloading blob_684
#  Time elapsed 12804.281029701233
#
# Downloading blob_685
#  Time elapsed 12804.397588968277
#
# Downloading blob_686
#  Time elapsed 12838.646671772003
#
# Downloading blob_687
#
#  Time elapsed 12840.70074558258
# Downloading blob_688
# Downloading blob_689
#  Time elapsed 12879.175741434097
#
#
#  Time elapsed 12879.176362752914
# Downloading blob_690
#  Time elapsed 12913.138524055481
#
# Downloading blob_691
#  Time elapsed 12919.780347585678
#
# Downloading blob_692
#  Time elapsed 12960.276798248291
#
# Downloading blob_693
#  Time elapsed 12961.112937688828
#
# Downloading blob_694
#  Time elapsed 13001.133987426758
#
# Downloading blob_695
#  Time elapsed 13001.737139225006
#
# Downloading blob_696
#  Time elapsed 13043.676692962646
#
# Downloading blob_697
#  Time elapsed 13044.067774295807
#
# Downloading blob_698
# Downloading blob_699
#  Time elapsed 13087.59728050232
#
#
#  Time elapsed 13087.600235462189
# Downloading blob_700
# Downloading blob_701
#  Time elapsed 13130.384249925613
#
#  Time elapsed 13130.385148525238
#
# Downloading blob_702
#  Time elapsed 13163.700461864471
#
# Downloading blob_703
#  Time elapsed 13169.818635940552
#
# Downloading blob_704
#
#  Time elapsed 13205.29561328888
# Downloading blob_705
#
#  Time elapsed 13207.597408771515
# Downloading blob_706
#  Time elapsed 13246.241503953934
#
# Downloading blob_707
#  Time elapsed 13247.427038669586
#
# Downloading blob_708
#  Time elapsed 13280.799277305603
#
# Downloading blob_709
#  Time elapsed 13284.151865005493
#
# Downloading blob_710
# Downloading blob_711
#  Time elapsed 13329.992273330688
#
#  Time elapsed 13329.99238562584
#
# Downloading blob_712
# Downloading blob_713
#  Time elapsed 13373.374718427658
#
#  Time elapsed 13373.374866485596
#
# Downloading blob_714
#  Time elapsed 13410.44917011261
#
# Downloading blob_715
#
#  Time elapsed 13411.590633392334
# Downloading blob_716
#  Time elapsed 13448.212816953659
#
# Downloading blob_717
#  Time elapsed 13448.788482666016
#
# Downloading blob_718
# Downloading blob_719
#  Time elapsed 13489.136717557907
#
#  Time elapsed 13489.136877775192
#
# Downloading blob_720
#  Time elapsed 13528.099442958832
#
# Downloading blob_721
#  Time elapsed 13529.055450201035
#
# Downloading blob_722
#  Time elapsed 13567.020862817764
#
# Downloading blob_723
#
#  Time elapsed 13567.831798791885
# Downloading blob_724
# Downloading blob_725
#
#  Time elapsed 13611.90329003334
#
#  Time elapsed 13611.903453826904
# Downloading blob_726
#  Time elapsed 13656.882832050323
#
# Downloading blob_727
#  Time elapsed 13657.149322032928
#
# Downloading blob_728
#  Time elapsed 13693.711287736893
#
# Downloading blob_729
#  Time elapsed 13694.648428201675
#
# Downloading blob_730
# Downloading blob_731
#
#  Time elapsed 13733.459805727005
#
#  Time elapsed 13733.462734937668
# Downloading blob_732
# Downloading blob_733
#
#  Time elapsed 13768.056570768356
#
#  Time elapsed 13768.056674003601
# Downloading blob_734
#  Time elapsed 13806.008080720901
#
# Downloading blob_735
#  Time elapsed 13806.012805223465
#
# Downloading blob_736
# Downloading blob_737
#  Time elapsed 13845.543158769608
#
#
#  Time elapsed 13845.543986082077
# Downloading blob_738
#
#  Time elapsed 13883.008227348328
# Downloading blob_739
#
#  Time elapsed 13886.450597047806
# Downloading blob_740
#  Time elapsed 13928.518323421478
#
# Downloading blob_741
#  Time elapsed 13931.261280298233
#
# Downloading blob_742
#  Time elapsed 13963.880135774612
#
# Downloading blob_743
#  Time elapsed 13970.041148900986
#
# Downloading blob_744
#  Time elapsed 14005.31915974617
#
# Downloading blob_745
#  Time elapsed 14006.428550720215
#
# Downloading blob_746
#  Time elapsed 14047.62540268898
#
# Downloading blob_747
#  Time elapsed 14048.524538040161
#
# Downloading blob_748
#
#  Time elapsed 14086.712002754211
# Downloading blob_749
#  Time elapsed 14087.242019891739
#
# Downloading blob_750
# Downloading blob_751
#  Time elapsed 14127.740401506424
#
#
#  Time elapsed 14127.740608215332
# Downloading blob_752
# Downloading blob_753
#  Time elapsed 14171.805167675018
#
#  Time elapsed 14171.805392742157
#
# Downloading blob_754
#  Time elapsed 14212.255154132843
#
# Downloading blob_755
#
#  Time elapsed 14212.578097105026
# Downloading blob_756
#
#  Time elapsed 14257.013055801392
# Downloading blob_757
#  Time elapsed 14258.6609146595
#
# Downloading blob_758
# Downloading blob_759
#  Time elapsed 14297.354847192764
#
#  Time elapsed 14297.355138778687
#
# Downloading blob_760
# Downloading blob_761
#  Time elapsed 14338.441980600357
#
#  Time elapsed 14338.44220161438
#
# Downloading blob_762
#  Time elapsed 14374.362092971802
#
# Downloading blob_763
#  Time elapsed 14375.22964477539
#
# Downloading blob_764
# Downloading blob_765
#  Time elapsed 14421.109503984451
#
#
#  Time elapsed 14421.110549211502
# Downloading blob_766
#  Time elapsed 14463.608272314072
#
# Downloading blob_767
#  Time elapsed 14464.844296216965
#
# Downloading blob_768
#  Time elapsed 14504.152755260468
#
# Downloading blob_769
#  Time elapsed 14505.6404941082
#
# Downloading blob_770Downloading blob_771
#
#  Time elapsed 14547.815844774246
#
#  Time elapsed 14547.816003084183
#
# Downloading blob_772Downloading blob_773
#  Time elapsed 14592.075311422348
#
#  Time elapsed 14592.075412988663
#
#
# Downloading blob_774
#  Time elapsed 14638.475577116013
#
# Downloading blob_775
#  Time elapsed 14639.091596603394
#
# Downloading blob_776
#  Time elapsed 14677.219291687012
#
# Downloading blob_777
#
#  Time elapsed 14677.888295412064
# Downloading blob_778
# Downloading blob_779
#  Time elapsed 14721.66519856453
#
#  Time elapsed 14721.665315628052
#
# Downloading blob_780
#  Time elapsed 14756.408272743225
#
# Downloading blob_781
#  Time elapsed 14757.922588348389
#
# Downloading blob_782
# Downloading blob_783
#  Time elapsed 14798.625344276428
#
#  Time elapsed 14798.62554526329
# Downloading blob_784
#  Time elapsed 14834.618936777115
#
# Downloading blob_785
#  Time elapsed 14835.225970506668
#
# Downloading blob_786
#  Time elapsed 14872.77053141594
#
# Downloading blob_787
#  Time elapsed 14873.366738796234
#
# Downloading blob_788
# Downloading blob_789
#  Time elapsed 14912.959205389023
#
#
#  Time elapsed 14912.959699630737
# Downloading blob_790
#  Time elapsed 14954.18170285225
#
# Downloading blob_791
#  Time elapsed 14954.365981340408
#
# Downloading blob_792
#  Time elapsed 14992.468943119049
#
# Downloading blob_793
#
#  Time elapsed 14993.882733106613
# Downloading blob_794
#  Time elapsed 15030.570506811142
#
# Downloading blob_795
#  Time elapsed 15031.521943569183
#
# Downloading blob_796
#  Time elapsed 15070.604353427887
#
# Downloading blob_797
#
#  Time elapsed 15071.566086053848
#
#  Time elapsed 15108.717267990112
#
#  Time elapsed 15108.717420101166
# Total time taken 15108.721873998642

# %%
# VALIDATION
# val blobs
blobs = [blob for blob in storage_client.list_blobs(bucket_name, prefix='validation/')]

start = time.time()
downloaded_blobs = []

thread_iterable = ((blob,blob_idx, 'validation') for blob_idx, blob in enumerate(blobs))

with concurr.ThreadPoolExecutor(max_workers = 2) as executor:

    results = executor.map(lambda args: download_process_save_1_blob(*args), thread_iterable)
    for r in results:
        print(f'\n Time elapsed {time.time() - start}')
        downloaded_blobs.append(r)
        
end = time.time()
print(f'Total time taken {end - start}')

# %%
# USED TO LOOK AT BLOB AGAIN

# Initialise a client
storage_client = storage.Client(project= project) #storage.Client(project= "Waymo3DObjectDetection", credentials=credentials)
# Create a bucket object for our bucket
bucket = storage_client.get_bucket(bucket_name)
# Get blob files in bucket
blobs = [blob for blob in storage_client.list_blobs(bucket_name, prefix='validation/')]

n_blobs = len(blobs) # Number of blobs in the training dataset
print(f'Total number of blobs is {n_blobs}')
# Out:
# /usr/local/lib/python3.6/dist-packages/google/auth/_default.py:69: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# Total number of blobs is 202

# %%
# blob_fname = download_blob(blobs[0], 0)
dataset = tf.data.TFRecordDataset(blob_fname, compression_type='')
for c,data in enumerate(dataset):
    frame = open_dataset.Frame()
    frame.ParseFromString(bytearray(data.numpy()))
    if frame.no_label_zones:
        print(frame.no_label_zones)

# %%
frame.
# Out:
# []
